# %%
import pandas as pd

data = pd.read_csv("C:/Users/HP/Documents/Learning/BostonHousing.csv")
data.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
data.tail(10)
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 496  0.28960  0.0   9.69     0  0.585  5.390  72.9  2.7986    6  391     19.2
# 497  0.26838  0.0   9.69     0  0.585  5.794  70.6  2.8927    6  391     19.2
# 498  0.23912  0.0   9.69     0  0.585  6.019  65.3  2.4091    6  391     19.2
# 499  0.17783  0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391     19.2
# 500  0.22438  0.0   9.69     0  0.585  6.027  79.7  2.4982    6  391     19.2
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#           b  lstat  medv
# 496  396.90  21.14  19.7
# 497  396.90  14.10  18.3
# 498  396.90  12.92  21.2
# 499  395.77  15.10  17.5
# 500  396.90  14.33  16.8
# 501  391.99   9.67  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %%
data.shape
# Out:
# (506, 14)

# %%
data.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  501.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284341
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.705587
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.884000
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208000
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.625000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             lstat        medv
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
import seaborn as sns

sns.displot(data['medv'])

# %%
sns.histplot(data['dis'])
# Out:
# <Axes: xlabel='dis', ylabel='Count'>

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data = data.drop_duplicates()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       501 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
data.corr()['medv']
# Out:
# crim      -0.388305
# zn         0.360445
# indus     -0.483725
# chas       0.175260
# nox       -0.427321
# rm         0.696169
# age       -0.376955
# dis        0.249929
# rad       -0.381626
# tax       -0.468536
# ptratio   -0.507787
# b          0.333461
# lstat     -0.737663
# medv       1.000000
# Name: medv, dtype: float64

# %% [markdown]
# ## Preparing the Data

# %%
# Split data into Feature and Target

x = pd.DataFrame(data[['lstat', 'rm']])
y =  pd.DataFrame(data['medv'])
x
# Out:
#      lstat     rm
# 0     4.98  6.575
# 1     9.14  6.421
# 2     4.03  7.185
# 3     2.94  6.998
# 4     5.33  7.147
# ..     ...    ...
# 501   9.67  6.593
# 502   9.08  6.120
# 503   5.64  6.976
# 504   6.48  6.794
# 505   7.88  6.030
#
# [506 rows x 2 columns]

# %%
print(x.size, y.size)
# Out:
# 1012 506

# %%
# Split data into training and testing

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 20)

# %%
x_train
# Out:
#      lstat     rm
# 7    19.15  6.172
# 268   3.16  7.470
# 80    5.29  6.727
# 30   22.60  5.713
# 450  17.44  6.749
# ..     ...    ...
# 412  34.37  4.628
# 223   7.60  6.618
# 271   6.59  6.240
# 474  18.14  5.427
# 355   5.57  5.936
#
# [404 rows x 2 columns]

# %%
x_train
# Out:
#      lstat     rm
# 7    19.15  6.172
# 268   3.16  7.470
# 80    5.29  6.727
# 30   22.60  5.713
# 450  17.44  6.749
# ..     ...    ...
# 412  34.37  4.628
# 223   7.60  6.618
# 271   6.59  6.240
# 474  18.14  5.427
# 355   5.57  5.936
#
# [404 rows x 2 columns]

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)
y_pred
# Out:
# array([[21.18639527],
#        [23.8755585 ],
#        [20.91803274],
#        [16.25256806],
#        [14.73658658],
#        [23.92407214],
#        [11.08744237],
#        [ 6.66306994],
#        [21.37098104],
#        [22.87135948],
#        [24.10746325],
#        [16.34786398],
#        [27.1301771 ],
#        [25.07242658],
#        [22.50550057],
#        [27.73560861],
#        [29.87053151],
#        [18.62897778],
#        [15.6933245 ],
#        [19.88283536],
#        [37.73991758],
#        [37.87560508],
#        [25.89153594],
#        [29.46182809],
#        [20.14293372],
#        [26.29612465],
#        [23.33182555],
#        [26.97217285],
#        [21.78057895],
#        [25.83559895],
#        [20.79313886],
#        [19.08956708],
#        [20.21751901],
#        [12.57074584],
#        [28.83915662],
#        [24.62631325],
#        [39.73017321],
#        [27.46140003],
#        [22.13167366],
#        [32.88390778],
#        [ 4.91313729],
#        [17.47784343],
#        [23.0732717 ],
#        [15.33188242],
#        [24.62492262],
#        [26.42971903],
#        [23.33654055],
#        [24.9670278 ],
#        [ 7.83745032],
#        [16.46379101],
#        [35.45292493],
#        [31.61191175],
#        [13.16481621],
#        [34.83350248],
#        [17.37244646],
#        [25.38959893],
#        [18.1114417 ],
#        [18.97100426],
#        [19.04830187],
#        [17.7869633 ],
#        [28.25935051],
#        [23.15311465],
#        [21.59136862],
#        [24.50570383],
#        [16.93632088],
#        [17.34672086],
#        [26.23576686],
#        [27.28915636],
#        [21.5011475 ],
#        [19.5805773 ],
#        [32.21119904],
#        [22.74444403],
#        [26.5185994 ],
#        [24.75335194],
#        [18.8519932 ],
#        [25.21554538],
#        [26.19883003],
#        [26.58088831],
#        [26.44660716],
#        [19.72113782],
#        [ 6.83626179],
#        [16.65557352],
#        [26.61033819],
#        [ 4.7394336 ],
#        [30.7762492 ],
#        [21.70169609],
#        [21.90946428],
#        [18.55639517],
#        [26.31680049],
#        [24.15436083],
#        [23.11101854],
#        [26.80897256],
#        [20.81776242],
#        [12.6365382 ],
#        [24.57932722],
#        [27.95107148],
#        [20.41842739],
#        [18.34313476],
#        [18.93710674],
#        [21.81533619],
#        [16.47286918],
#        [26.3275961 ]])

# %%
y_pred = pd.DataFrame(y_pred, columns = ['Predicted'])
y_pred
# Out:
#      Predicted
# 0    21.186395
# 1    23.875559
# 2    20.918033
# 3    16.252568
# 4    14.736587
# ..         ...
# 97   18.343135
# 98   18.937107
# 99   21.815336
# 100  16.472869
# 101  26.327596
#
# [102 rows x 1 columns]

# %%
df_pred = pd.DataFrame(columns = ['Actual', 'Pred'])
df_pred['Actual'] = y_test.reset_index()['medv']
df_pred['Pred'] = y_pred.reset_index()['Predicted']
df_pred
# Out:
#      Actual       Pred
# 0      21.2  21.186395
# 1      20.6  23.875559
# 2      21.5  20.918033
# 3      21.7  16.252568
# 4      13.4  14.736587
# ..      ...        ...
# 97     18.9  18.343135
# 98     13.0  18.937107
# 99     22.6  21.815336
# 100    19.5  16.472869
# 101    23.8  26.327596
#
# [102 rows x 2 columns]

# %%
df_pred['Error'] = df_pred.Actual - df_pred.Pred
df_pred
# Out:
#      Actual       Pred     Error
# 0      21.2  21.186395  0.013605
# 1      20.6  23.875559 -3.275559
# 2      21.5  20.918033  0.581967
# 3      21.7  16.252568  5.447432
# 4      13.4  14.736587 -1.336587
# ..      ...        ...       ...
# 97     18.9  18.343135  0.556865
# 98     13.0  18.937107 -5.937107
# 99     22.6  21.815336  0.784664
# 100    19.5  16.472869  3.027131
# 101    23.8  26.327596 -2.527596
#
# [102 rows x 3 columns]

# %%
from sklearn import metrics
import numpy as np

print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error:  4.087221705996977
# Mean Squared Error:  26.855534007089734
# Root Mean Squared Error:  5.182232531167405

# %%
metrics.mean_absolute_percentage_error(y_test, y_pred)*100
# Out:
# 21.976104085851393

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.5830238079319465

# %%
x_train.isnull().sum()
# Out:
# lstat    0
# rm       0
# dtype: int64

# %%
x_train = x_train.fillna(x_train.mean())
x_test = x_test.fillna(x_test.mean())

# %% [markdown]
# ## Multiple Linear Regression

# %%
import pandas as pd
dataset = pd.read_csv("C:/Users/HP/Documents/Learning/BostonHousing.csv")
dataset.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
x = pd.DataFrame(dataset.iloc[:, :-1])
y = pd.DataFrame(dataset.iloc[:, -1])
y
# Out:
#      medv
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# ..    ...
# 501  22.4
# 502  20.6
# 503  23.9
# 504  22.0
# 505  11.9
#
# [506 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 20)

# %%
x_train['rm'] = x_train['rm'].fillna(x_train['rm'].mean())

# %%
x_train.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# dtype: int64

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (404, 13)
# (102, 13)
# (404, 1)
# (102, 1)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[-6.99411583e-02,  4.09454036e-02,  4.75734619e-02,
#          2.94882403e+00, -2.11812306e+01,  3.74856701e+00,
#          1.86471998e-02, -1.33440996e+00,  2.71966449e-01,
#         -1.12476734e-02, -9.01609192e-01,  9.09882371e-03,
#         -5.66620000e-01]])

# %%
model.intercept_
# Out:
# array([36.22188464])

# %%
v =  pd.DataFrame(model.coef_, index = ['Co-efficient']).transpose()
w = pd.DataFrame(x.columns, columns = ['Attribute'])

# %%
coeff_df = pd.concat([w, v], axis = 1, join='inner')
coeff_df
# Out:
#    Attribute  Co-efficient
# 0       crim     -0.069941
# 1         zn      0.040945
# 2      indus      0.047573
# 3       chas      2.948824
# 4        nox    -21.181231
# 5         rm      3.748567
# 6        age      0.018647
# 7        dis     -1.334410
# 8        rad      0.271966
# 9        tax     -0.011248
# 10   ptratio     -0.901609
# 11         b      0.009099
# 12     lstat     -0.566620

# %%
x_test.isnull().sum()
x_test['rm'] = x_test['rm'].fillna(x_test['rm'].mean())

# %%
y_pred = model.predict(x_test)
y_pred = pd.DataFrame(y_pred, columns = ['Predicted'])
y_pred
# Out:
#      Predicted
# 0    21.054342
# 1    27.547622
# 2    20.168745
# 3    23.910889
# 4    13.001133
# ..         ...
# 97   19.295625
# 98   17.076517
# 99   18.754404
# 100  17.466930
# 101  26.003289
#
# [102 rows x 1 columns]

# %%
from sklearn import metrics

print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Square Error: ', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Square Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error:  3.081336490587122
# Mean Square Error:  16.70816553704941
# Root Mean Square Error:  4.08756229763528

# %%
from sklearn.metrics import r2_score

r2_score(y_test, y_pred)
# Out:
# 0.7405783388912572
